# %%
######################## Screenshot and Image Recognition #########################

# %%
# !pip install pyautogui
import pyautogui
pyautogui.screenshot()
# Out:
# <PIL.Image.Image image mode=RGB size=1366x768 at 0x27AB5433580>

# %%
pyautogui.screenshot("D:\\screenshot.png")
# Out:
# <PIL.Image.Image image mode=RGB size=1366x768 at 0x27AB66FEE80>

# %%
pyautogui.locateOnScreen("D:\\screenshot.png") # pass a sample image file and returns the coordinate of where it is on screen
pyautogui.locateCenterOnScreen("D:\\screenshot.png") # returns tuple (x,y) of where the image is on the screen
